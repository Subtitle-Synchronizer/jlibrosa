# %%
import librosa

# %%
x,sr = librosa.load('../audioFiles/AClassicEducation.wav', sr=None,duration=5)

# %%
x[0:10]
# Out:
# array([0.00889587, 0.02452087, 0.04592896, 0.06182861, 0.06054688,
#        0.05015564, 0.0463562 , 0.05368042, 0.06311035, 0.06074524],
#       dtype=float32)

# %%
len(x)
# Out:
# 220500

# %%
mfccs = librosa.feature.mfcc(x, sr, n_mfcc=40)

# %%
mfccs.shape
# Out:
# (40, 431)

# %%
mfccs[1]
# Out:
# array([186.36444 , 190.08183 , 185.0048  , 178.63866 , 180.81296 ,
#        181.71564 , 181.74538 , 178.21866 , 179.801   , 180.30203 ,
#        177.22534 , 176.26743 , 174.4388  , 174.82654 , 177.04912 ,
#        180.099   , 178.41705 , 172.61365 , 165.52863 , 161.73273 ,
#        160.93375 , 159.6849  , 162.45502 , 168.64758 , 164.35742 ,
#        161.22723 , 164.63458 , 175.75647 , 176.66861 , 180.03937 ,
#        183.78952 , 182.4284  , 182.95085 , 185.97409 , 184.3285  ,
#        180.74866 , 181.42715 , 178.12415 , 183.41547 , 194.0834  ,
#        198.07133 , 201.63719 , 208.72351 , 211.61185 , 210.71751 ,
#        217.12836 , 214.90097 , 210.42686 , 181.74113 , 164.36478 ,
#        157.19847 , 158.56966 , 160.83003 , 163.42212 , 164.19644 ,
#        164.35397 , 163.54517 , 174.11263 , 183.29712 , 193.05376 ,
#        205.26901 , 206.53214 , 199.78754 , 198.86658 , 198.69913 ,
#        199.70624 , 200.4728  , 198.12065 , 202.33517 , 208.35683 ,
# ...

# %%
stft = librosa.stft(x, sr)

# %%
stft.shape
# Out:
# (22051, 21)

# %%
stft[0]
# Out:
# array([ 1.9195867 +0.j,  1.5532879 +0.j,  0.9053089 +0.j,  0.14452171+0.j,
#        -0.05089398+0.j,  0.5717887 +0.j,  1.2309817 +0.j,  0.50947976+0.j,
#        -0.30202052+0.j,  0.50456595+0.j,  0.8565632 +0.j,  0.7867331 +0.j,
#         0.7643999 +0.j,  0.6175232 +0.j,  0.8052668 +0.j,  0.26852855+0.j,
#        -0.33250943+0.j, -1.1016625 +0.j, -2.0493436 +0.j,  9.0469    +0.j,
#        20.225245  +0.j], dtype=complex64)
